# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Times New Roman + SimSun + WFM Sans SC']
plt.rcParams['mathtext.fontset']='stix'
# Times New Roman + SimSun + WFM Sans SC
# simsum宋体, times new roman -*, simhei黑体, kaiti楷体, 
# dengxian等线, fangsong仿宋, Microsoft Yahei微软雅黑
plt.rcParams['axes.unicode_minus']=False   
plt.rcParams['figure.dpi'] = 200
# plt.rcParams['figure.figsize'] = [4, 3]
# plt.rcParams['font.size'] = 12
plt.rcParams['xtick.direction']='in'
plt.rcParams['ytick.direction']='in'

# %%
import pandas as pd
df = pd.DataFrame([[13, 10, 27, 33, 30, 45], [1, 10, 7, 26, 20, 25]], index=[u'钻石', u'铂金'], columns=[str(i)+'月' for i in range(1, 7)])
df
# Out:
#     1月  2月  3月  4月  5月  6月
# 钻石  13  10  27  33  30  45
# 铂金   1  10   7  26  20  25

# %%
x = df.columns
y1 = df.iloc[0]
y2 = df.iloc[1]
id = df.index
plt.title('商品销售趋势图\nChange Energy')
plt.plot(x, y1, '-*b', label='钻石')
plt.plot(x, y2, '--dr', label='铂金')
plt.xlabel('月份')
plt.ylabel('每月销量')
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ***

# %%
df.T.plot(kind='bar')
plt.xticks(range(6), x, rotation=0)
plt.title("销售数据柱状图")
plt.xlabel("月份")
plt.ylabel("数量")
plt.legend()

# %%
import numpy as np
plt.rcParams['text.usetex'] = False
y1 = np.random.randint(2, 5, 6)
y1 = y1/sum(y1)
plt.subplot(221)
s = ['apple', 'grape', 'peach', 'pear', 'banana', 'pineapple']
plt.barh(s, y1)
plt.subplot(222)
plt.pie(y1, labels=s, shadow=True, radius=1.2)
plt.subplot(212)
x2 = np.linspace(0.01, 10, 100)
y2 = np.sin(10*x2)/x2
plt.plot(x2, y2)
plt.xlabel('$x$')
plt.ylabel('$\sin{(10x)}/x$')
# Out:
# Text(0, 0.5, '$\\sin{(10x)}/x$')

# %%
ax = plt.axes(projection='3d')
s = np.linspace(-50, 50, 1000)
x = s**2*np.sin(s)
y = s**2*np.cos(s)
z = s
ax.plot(x, y, z, 'r')

# %%
x = np.linspace(-4, 4, 100)
x, y = np.meshgrid(x, x)
z = 50*np.sin(x + y)
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z, color='c')
ax.set_zlabel('z')
plt.show()

# %%
ax = plt.axes(projection='3d')
x = np.arange(-6, 6, 0.01)
y = np.arange(-6, 6, 0.01)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))
surf = ax.plot_surface(x, y, z, cmap='inferno')
plt.colorbar(surf)
plt.show()
